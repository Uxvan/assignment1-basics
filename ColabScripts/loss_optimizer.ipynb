# %%
import os
import shutil
# !pip install uv
# !git clone https://github.com/Uxvan/assignment1-basics.git
os.chdir('/content/assignment1-basics')
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 83.3 MB/s eta 0:00:00
# ...
# Cloning into 'assignment1-basics'...
# remote: Enumerating objects: 860, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 860 (delta 192), reused 128 (delta 128), pack-reused 662 (from 3)
# Receiving objects: 100% (860/860), 14.50 MiB | 16.14 MiB/s, done.
# Resolving deltas: 100% (545/545), done.

# %%
# 更新
# 1. 先退回到 /content 根目录（非常重要！如果在 assignment1-basics 目录内部是无法删除该目录的）
os.chdir('/content')

# 2. 删除旧的代码文件夹
if os.path.exists('/content/assignment1-basics'):
    shutil.rmtree('/content/assignment1-basics')

# 3. 重新克隆仓库
# !git clone https://github.com/Uxvan/assignment1-basics.git

# 4. 再次进入目录
os.chdir('/content/assignment1-basics')
# Out:
# Cloning into 'assignment1-basics'...
# remote: Enumerating objects: 868, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 868 (delta 196), reused 128 (delta 128), pack-reused 662 (from 3)
# Receiving objects: 100% (868/868), 14.51 MiB | 17.96 MiB/s, done.
# Resolving deltas: 100% (549/549), done.

# %% [markdown]
# 以下为测试

# %%
# !uv run pytest -k test_cross_entropy
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 322ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.9, timeout-2.4.0
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_nn_utils.py::test_cross_entropy PASSED
#
# ======================= 1 passed, 47 deselected in 0.22s =======================

# %%
# !uv run pytest -k test_adamw
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 313ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: timeout-2.4.0, jaxtyping-0.3.9
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_optimizer.py::test_adamw PASSED
#
# ======================= 1 passed, 47 deselected in 7.31s =======================

# %%
# !uv run pytest -k test_get_lr_cosine_schedule
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 381ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: timeout-2.4.0, jaxtyping-0.3.9
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_optimizer.py::test_get_lr_cosine_schedule PASSED
#
# ======================= 1 passed, 47 deselected in 0.16s =======================

# %%
# !uv run pytest -k test_gradient_clipping
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 275ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: timeout-2.4.0, jaxtyping-0.3.9
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_nn_utils.py::test_gradient_clipping PASSED
#
# ======================= 1 passed, 47 deselected in 0.27s =======================

# %%
# !uv run pytest -k test_get_batch
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 293ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: timeout-2.4.0, jaxtyping-0.3.9
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_data.py::test_get_batch PASSED
#
# ======================= 1 passed, 47 deselected in 0.59s =======================

# %%
# !uv run pytest -k test_checkpointing
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 306ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: timeout-2.4.0, jaxtyping-0.3.9
# collected 48 items / 47 deselected / 1 selected
#
# tests/test_serialization.py::test_checkpointing PASSED
#
# ======================= 1 passed, 47 deselected in 4.29s =======================
