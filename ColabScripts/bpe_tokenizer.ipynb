# %%
import os
# !pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 85.6 MB/s eta 0:00:00
# ...

# %%
# !git clone https://github.com/Uxvan/assignment1-basics.git
os.chdir('/content/assignment1-basics')
# Out:
# Cloning into 'assignment1-basics'...
# remote: Enumerating objects: 530, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 530 (delta 62), reused 32 (delta 32), pack-reused 459 (from 3)
# Receiving objects: 100% (530/530), 14.32 MiB | 16.11 MiB/s, done.
# Resolving deltas: 100% (306/306), done.

# %%
# !uv run pytest tests/test_train_bpe.py
# Out:
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Installed 66 packages in 526ms
# ============================= test session starts ==============================
# platform linux -- Python 3.12.13, pytest-9.0.2, pluggy-1.6.0
# rootdir: /content/assignment1-basics
# configfile: pyproject.toml
# plugins: jaxtyping-0.3.9, timeout-2.4.0
# collected 3 items
#
# tests/test_train_bpe.py::test_train_bpe_speed PASSED
# tests/test_train_bpe.py::test_train_bpe PASSED
# tests/test_train_bpe.py::test_train_bpe_special_tokens PASSED
#
# =============================== warnings summary ===============================
# tests/test_train_bpe.py::test_train_bpe_speed
#   /content/assignment1-basics/cs336_basics/train_bpe.py:19: SyntaxWarning: invalid escape sequence '\p'
#     PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ...

# %%
# !mkdir -p data
# !cd data

# !wget https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-train.txt
# !wget https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-valid.txt

# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_train.txt.gz
# !gunzip owt_train.txt.gz
# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_valid.txt.gz
# !gunzip owt_valid.txt.gz

# !cd ..
# Out:
# --2026-07-20 12:49:46--  https://huggingface.co/datasets/roneneldan/TinyStories/resolve/main/TinyStoriesV2-GPT4-train.txt
# Resolving huggingface.co (huggingface.co)... 3.173.161.4, 3.173.161.89, 3.173.161.3, ...
# Connecting to huggingface.co (huggingface.co)|3.173.161.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/645e8da96320b0efe40ade7a/02e40cc51c59a4bc6c51bd7bc9acda4316e208745be060558eaf500cd14e9f96?response-content-type=text%2Fplain&user_id=public&response-content-disposition=inline%3B+filename*%3DUTF-8%27%27TinyStoriesV2-GPT4-train.txt%3B+filename%3D%22TinyStoriesV2-GPT4-train.txt%22%3B&X-Xet-Cas-Uid=public&Expires=1784555386&Policy=...&Signature=MEYCIQDrgSxhd%7EU%7EI6iNG8erioSkcStC7lFIzISNgkPa4iFKugIhANqhMcED1CCfbbbi0rWUJmb5mlZOtrT8TT-f3a9dzP%7Eu&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# ...

# %%
# !pwd
# !ls -l
# Out:
# /content/assignment1-basics
# total 14123224
# -rw-r--r-- 1 root root        4852 Jul 20 12:07 AGENTS.md
# -rw-r--r-- 1 root root        7713 Jul 20 12:07 CHANGELOG.md
# -rw-r--r-- 1 root root        4852 Jul 20 12:07 CLAUDE.md
# -rw-r--r-- 1 root root      965629 Jul 20 12:07 cs336_assignment1_basics.pdf
# drwxr-xr-x 3 root root        4096 Jul 20 12:12 cs336_basics
# drwxr-xr-x 2 root root        4096 Jul 20 12:20 data
# -rw-r--r-- 1 root root        1067 Jul 20 12:07 LICENSE
# -rw-r--r-- 1 root root         857 Jul 20 12:07 make_submission.sh
# -rw-r--r-- 1 root root      109675 Jul 20 12:31 merges_tinystories.pkl
# -rw-r--r-- 1 root root 11920511059 Jul 20 12:52 owt_train.txt
# -rw-r--r-- 1 root root   289998753 Jul 20 12:54 owt_valid.txt
# -rw-r--r-- 1 root root        1113 Jul 20 12:07 pyproject.toml
# -rw-r--r-- 1 root root        1662 Jul 20 12:07 README.md
# drwxr-xr-x 4 root root        4096 Jul 20 12:07 tests
# ...

# %%
# 把当前目录下的文本文件移动到 data 文件夹中
# !mv TinyStoriesV2-GPT4-train.txt TinyStoriesV2-GPT4-valid.txt owt_train.txt owt_valid.txt data/

# %%
# !ls -l data
# Out:
# total 14121860
# -rw-r--r-- 1 root root 11920511059 Jul 20 12:52 owt_train.txt
# -rw-r--r-- 1 root root   289998753 Jul 20 12:54 owt_valid.txt
# -rw-r--r-- 1 root root  2227753162 Jul 20 12:50 TinyStoriesV2-GPT4-train.txt
# -rw-r--r-- 1 root root    22502601 Jul 20 12:50 TinyStoriesV2-GPT4-valid.txt

# %%
from cs336_basics.train_bpe import train_bpe

# %%
# TinyStories
vocab, merges = train_bpe(
    input_path="data/TinyStoriesV2-GPT4-train.txt",
    vocab_size=10000,
    special_tokens=["<|endoftext|>"]
)

# %%
# !mkdir -p data
# !cd data
# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_train.txt.gz
# !gunzip owt_train.txt.gz
# !wget https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_valid.txt.gz
# !gunzip owt_valid.txt.gz

# !cd ..
# Out:
# --2026-07-20 13:09:46--  https://huggingface.co/datasets/stanford-cs336/owt-sample/resolve/main/owt_train.txt.gz
# Resolving huggingface.co (huggingface.co)... 18.164.174.17, 18.164.174.23, 18.164.174.118, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.17|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://us.gcp.cdn.hf.co/xet-bridge-us/660add462617cc957fd1bc02/58fb91c989ef15907630f573127276d4db6662ab4aff77b929f901146ee9f208?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27owt_train.txt.gz%3B+filename%3D%22owt_train.txt.gz%22%3B&user_id=public&X-Xet-Cas-Uid=public&response-content-type=application%2Fgzip&Expires=1784556586&Policy=...&Signature=MEUCIQCjCXiRVyaQIaXqFNau-F%7EfWiq9lNnKUtQqWaxKtAeidQIgT0tb6UrhEIb%7EYc55pBaK8lCFM0bQelrDaOdXLlvbHSE_&Key-Pair-Id=01KXEF4KZ1B6FV465MAWR4M21F [following]
# ...

# %%
# !mv owt_train.txt owt_valid.txt data/

# %%
# OpenWebText
vocab, merges = train_bpe(
    input_path="data/owt_train.txt",
    vocab_size=32000,
    special_tokens=["<|endoftext|>"]
)
